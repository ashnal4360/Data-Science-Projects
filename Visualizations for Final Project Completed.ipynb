# %%
import pandas as pd
import numpy as np

# %%
Attending_College = pd.read_csv(r'C:\Users\ashna\OneDrive\Documents\School\UMGC\Capstone Two - Final Project\Attending College\college.csv')

# %%
Attending_College.head()
# Out:
#    StudentID  Gender  Parent_income   IQ      Encourage      Plan
# 0       4558    male          53900  118      encourage      plan
# 1       4561  female          24900   87  not encourage  not plan
# 2       4563  female          65800   93  not encourage  not plan
# 3       4565    male          11440  117      encourage      plan
# 4       4567  female          16700  102  not encourage  not plan

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# %%
sns.barplot(x = 'Gender',
            y = 'IQ',
            hue = 'Plan',
            data = Attending_College,
           palette = 'Wistia')

plt.show()

# %%
import seaborn as sns

sns.set_style('whitegrid')
fig,ax = plt.subplots(figsize=(15,7))


chart=sns.lineplot(x='IQ', y='Parent_income', hue='Plan', data=Attending_College)
sns.despine(left=True)

# %%
sns.barplot(x = 'Gender',
            y = 'Parent_income',
            hue = 'Encourage',
            data = Attending_College,
           palette = 'YlGnBu')

plt.show()

# %%
Student_Success = pd.read_csv(r'C:\Users\ashna\OneDrive\Documents\School\UMGC\Capstone Two - Final Project\Prediction of Student success\dataset.csv')

# %%
Student_Success.head()
# Out:
#    Marital status  Application mode  Application order  Course  \
# 0               1                 8                  5       2
# 1               1                 6                  1      11
# 2               1                 1                  5       5
# 3               1                 8                  2      15
# 4               2                12                  1       3
#
#    Daytime/evening attendance  Previous qualification  Nacionality  \
# 0                           1                       1            1
# 1                           1                       1            1
# 2                           1                       1            1
# 3                           1                       1            1
# 4                           0                       1            1
#
#    Mother's qualification  Father's qualification  Mother's occupation  ...  \
# 0                      13                      10                    6  ...
# ...

# %%
sns.barplot(x = 'Target',
            y = 'GPA',
            data = Student_Success,
           palette = 'gnuplot2')

plt.show()

# %%
student = pd.read_csv(r'C:\Users\ashna\OneDrive\Documents\School\UMGC\Capstone Two - Final Project\student performance dataset\study_performance.csv')

# %%
student
# Out:
#      gender race_ethnicity parental_level_of_education         lunch  \
# 0    female        group B           bachelor's degree      standard
# 1    female        group C                some college      standard
# 2    female        group B             master's degree      standard
# 3      male        group A          associate's degree  free/reduced
# 4      male        group C                some college      standard
# ..      ...            ...                         ...           ...
# 995  female        group E             master's degree      standard
# 996    male        group C                 high school  free/reduced
# 997  female        group C                 high school  free/reduced
# 998  female        group D                some college      standard
# 999  female        group D                some college  free/reduced
#
#     test_preparation_course  math_score  reading_score  writing_score
# ...

# %%
sns.barplot(x = 'test_preparation_course',
            y = 'math_score',
            data = student,
            hue = 'gender',
           palette = 'mako')

plt.show()

# %%
sns.barplot(x = 'test_preparation_course',
            y = 'reading_score',
              hue = 'gender',
            data = student,
          palette = "Oranges")

plt.show()

# %%
sns.barplot(x = 'test_preparation_course',
            y = 'writing_score',
            hue = 'gender',
            data = student,
            palette = "Reds")

plt.show()

# %%
sns.barplot(x = 'gender',
            y = 'math_score',
            data = student,
            palette = "Blues")

plt.show()

# %%
sns.barplot(x = 'gender',
            y = 'reading_score',
            data = student,
           palette = 'Purples')

plt.show()

# %%
sns.barplot(x = 'gender',
            y = 'writing_score',
            data = student,
           palette = 'Greens')

plt.show()
